# %% [markdown]
# # Spectral Tool in Python for Image Processing

# %%
#importing the package
from spectral import *

#importing dataset
img = open_image('92AV3C.lan')

# %%
img.__class__
# Out:
# spectral.io.bilfile.BilFile

# %%
print(img)
# Out:
# 	Data Source:   '.\.\92AV3C.lan'
# 	# Rows:            145
# 	# Samples:         145
# 	# Bands:           220
# 	Interleave:        BIL
# 	Quantization:  16 bits
# 	Data format:     int16

# %%
img.shape
# Out:
# (145, 145, 220)

# %%
pixel = img[50, 100]

# %%
pixel.shape
# Out:
# (220,)

# %%
bands = img[:,:,5]

# %%
bands.shape
# Out:
# (145, 145, 1)

# %%
#loading the entire img

arr = img.load()
arr.__class__
# Out:
# spectral.image.ImageArray

# %%
print(arr.info())
# Out:
# 	# Rows:            145
# 	# Samples:         145
# 	# Bands:           220
# 	Data format:   float32

# %%
arr.shape
# Out:
# (145, 145, 220)

# %%
#for showing the HSI data

view = imshow(img,(25,19,9))

# %%
print(view)
# Out:
# ImageView object:
#   Display bands       :  (25, 19, 9)
#   Interpolation       :  <default>
#   RGB data limits     :
#     R: [2289.0, 7000.0]
#     G: [2775.0, 7307.0]
#     B: [3560.0, 7928.0]

# %%
#ground truth map

gt = open_image('92AV3GT.GIS').read_band(0)
view = imshow(classes = gt)

# %%
view = imshow(img, (30, 20, 10), classes=gt)
view.set_display_mode("overlay")
view.class_alpha = 0.5

# %% [markdown]
# ## PART-2

# %%
gt = open_image('92AV3GT.GIS').read_band(0)
view = imshow(classes = gt)

# %%
classes = create_training_classes(img, gt)

# %%
#Gaussian Maximum likelihood classification

gmlc = GaussianClassifier(classes)
# Out:
# spectral:INFO: Setting min samples to 220
# spectral:WARNING: Omitting class   1 : only 54 samples present
# spectral:WARNING: Omitting class   7 : only 26 samples present
# spectral:WARNING: Omitting class   9 : only 20 samples present
# spectral:WARNING: Omitting class  13 : only 212 samples present
# spectral:WARNING: Omitting class  16 : only 95 samples present
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done

# %%
clmap = gmlc.classify_image(img)
v = imshow(classes = clmap)
# Out:
# Classifying image...  0.Classifying image...  4.Classifying image...  8.Classifying image... 12.Classifying image... 16.Classifying image... 20.Classifying image... 24.Classifying image... 28.Classifying image... 32.Classifying image... 36.Classifying image... 40.Classifying image... 44.Classifying image... 48.Classifying image... 52.Classifying image... 56.Classifying image... 60.Classifying image... 64.Classifying image... 68.Classifying image... 72.Classifying image... 76.Classifying image... 80.Classifying image... 84.Classifying image... 88.Classifying image... 92.Classifying image... 96.Classifying image... 100.0Classifying image...done

# %%
gtresults = clmap * (gt != 0)
v = imshow(classes = gtresults)

# %%
gterrors = gtresults * (gtresults != gt)
v = imshow(classes=gterrors)

# %%
#dimensionality Reduction

pc = principal_components(img)
v = imshow(pc.cov)
# Out:
# Covariance.....  0.0Covariance.....  0.0Covariance.....  4.0Covariance.....  8.0Covariance..... 12.0Covariance..... 16.0Covariance..... 20.0Covariance..... 24.0Covariance..... 28.0Covariance..... 32.0Covariance..... 36.0Covariance..... 40.0Covariance..... 44.0Covariance..... 48.0Covariance..... 52.0Covariance..... 56.0Covariance..... 60.0Covariance..... 64.0Covariance..... 68.0Covariance..... 72.0Covariance..... 76.0Covariance..... 80.0Covariance..... 84.0Covariance..... 88.0Covariance..... 92.0Covariance..... 96.0Covariance.....done

# %%
pc_0999 = pc.reduce(fraction = 0.999)
len(pc_0999.eigenvalues)
# Out:
# 32

# %%
img_pc = pc_0999.transform(img)
v = imshow(img_pc[:,:,:3], stretch_all = True)

# %%
classes = create_training_classes(img_pc, gt)
gmlc = GaussianClassifier(classes)
clmap = gmlc.classify_image(img_pc)
clmap_trainig = clmap * (gt != 0)
v = imshow(classes=clmap_trainig)
# Out:
# spectral:INFO: Setting min samples to 32
# spectral:WARNING: Omitting class   7 : only 26 samples present
# spectral:WARNING: Omitting class   9 : only 20 samples present
# Covariance.....  0.0Covariance.....  0.0Covariance.....  1.9Covariance.....  3.7Covariance.....  5.6Covariance.....  7.4Covariance.....  9.3Covariance..... 11.1Covariance..... 13.0Covariance..... 14.8Covariance..... 16.7Covariance..... 18.5Covariance..... 20.4Covariance..... 22.2Covariance..... 24.1Covariance..... 25.9Covariance..... 27.8Covariance..... 29.6Covariance..... 31.5Covariance..... 33.3Covariance..... 35.2Covariance..... 37.0Covariance..... 38.9Covariance..... 40.7Covariance..... 42.6Covariance..... 44.4Covariance..... 46.3Covariance..... 48.1Covariance..... 50.0Covariance..... 51.9Covariance..... 53.7Covariance..... 55.6Covariance..... 57.4Covariance..... 59.3Covariance..... 61.1Covariance..... 63.0Covariance..... 64.8Covariance..... 66.7Covariance..... 68.5Covariance..... 70.4Covariance..... 72.2Covariance..... 74.1Covariance..... 75.9Covariance..... 77.8Covariance..... 79.6Covariance..... 81.5Covariance..... 83.3Covariance..... 85.2Covariance..... 87.0Covariance..... 88.9Covariance..... 90.7Covariance..... 92.6Covariance..... 94.4Covariance..... 96.3Covariance..... 98.1Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....  1.1Covariance.....  2.1Covariance.....  3.2Covariance.....  4.2Covariance.....  5.3Covariance.....  6.3Covariance.....  7.4Covariance.....  8.4Covariance.....  9.5Covariance..... 10.5Covariance..... 11.6Covariance..... 12.6Covariance..... 13.7Covariance..... 14.7Covariance..... 15.8Covariance..... 16.8Covariance..... 17.9Covariance..... 18.9Covariance..... 20.0Covariance..... 21.1Covariance..... 22.1Covariance..... 23.2Covariance..... 24.2Covariance..... 25.3Covariance..... 26.3Covariance..... 27.4Covariance..... 28.4Covariance..... 29.5Covariance..... 30.5Covariance..... 31.6Covariance..... 32.6Covariance..... 33.7Covariance..... 34.7Covariance..... 35.8Covariance..... 36.8Covariance..... 37.9Covariance..... 38.9Covariance..... 40.0Covariance..... 41.1Covariance..... 42.1Covariance..... 43.2Covariance..... 44.2Covariance..... 45.3Covariance..... 46.3Covariance..... 47.4Covariance..... 48.4Covariance..... 49.5Covariance..... 50.5Covariance..... 51.6Covariance..... 52.6Covariance..... 53.7Covariance..... 54.7Covariance..... 55.8Covariance..... 56.8Covariance..... 57.9Covariance..... 58.9Covariance..... 60.0Covariance..... 61.1Covariance..... 62.1Covariance..... 63.2Covariance..... 64.2Covariance..... 65.3Covariance..... 66.3Covariance..... 67.4Covariance..... 68.4Covariance..... 69.5Covariance..... 70.5Covariance..... 71.6Covariance..... 72.6Covariance..... 73.7Covariance..... 74.7Covariance..... 75.8Covariance..... 76.8Covariance..... 77.9Covariance..... 78.9Covariance..... 80.0Covariance..... 81.1Covariance..... 82.1Covariance..... 83.2Covariance..... 84.2Covariance..... 85.3Covariance..... 86.3Covariance..... 87.4Covariance..... 88.4Covariance..... 89.5Covariance..... 90.5Covariance..... 91.6Covariance..... 92.6Covariance..... 93.7Covariance..... 94.7Covariance..... 95.8Covariance..... 96.8Covariance..... 97.9Covariance..... 98.9Covariance.....done
# Classifying image...  0.Classifying image...  4.Classifying image...  8.Classifying image... 12.Classifying image... 16.Classifying image... 20.Classifying image... 24.Classifying image... 28.Classifying image... 32.Classifying image... 36.Classifying image... 40.Classifying image... 44.Classifying image... 48.Classifying image... 52.Classifying image... 56.Classifying image... 60.Classifying image... 64.Classifying image... 68.Classifying image... 72.Classifying image... 76.Classifying image... 80.Classifying image... 84.Classifying image... 88.Classifying image... 92.Classifying image... 96.Classifying image... 100.0Classifying image...done

# %%
training_errors = clmap_trainig * (clmap_trainig != gt)
v = imshow(classes=training_errors)

# %%
#Fisher linear discriminant algorithm

classes = create_training_classes(img, gt)
fld = linear_discriminant(classes)

len(fld.eigenvectors)
# Out:
# Covariance.....  0.0Covariance.....  0.0Covariance.....  1.9Covariance.....  3.7Covariance.....  5.6Covariance.....  7.4Covariance.....  9.3Covariance..... 11.1Covariance..... 13.0Covariance..... 14.8Covariance..... 16.7Covariance..... 18.5Covariance..... 20.4Covariance..... 22.2Covariance..... 24.1Covariance..... 25.9Covariance..... 27.8Covariance..... 29.6Covariance..... 31.5Covariance..... 33.3Covariance..... 35.2Covariance..... 37.0Covariance..... 38.9Covariance..... 40.7Covariance..... 42.6Covariance..... 44.4Covariance..... 46.3Covariance..... 48.1Covariance..... 50.0Covariance..... 51.9Covariance..... 53.7Covariance..... 55.6Covariance..... 57.4Covariance..... 59.3Covariance..... 61.1Covariance..... 63.0Covariance..... 64.8Covariance..... 66.7Covariance..... 68.5Covariance..... 70.4Covariance..... 72.2Covariance..... 74.1Covariance..... 75.9Covariance..... 77.8Covariance..... 79.6Covariance..... 81.5Covariance..... 83.3Covariance..... 85.2Covariance..... 87.0Covariance..... 88.9Covariance..... 90.7Covariance..... 92.6Covariance..... 94.4Covariance..... 96.3Covariance..... 98.1Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....  3.8Covariance.....  7.7Covariance..... 11.5Covariance..... 15.4Covariance..... 19.2Covariance..... 23.1Covariance..... 26.9Covariance..... 30.8Covariance..... 34.6Covariance..... 38.5Covariance..... 42.3Covariance..... 46.2Covariance..... 50.0Covariance..... 53.8Covariance..... 57.7Covariance..... 61.5Covariance..... 65.4Covariance..... 69.2Covariance..... 73.1Covariance..... 76.9Covariance..... 80.8Covariance..... 84.6Covariance..... 88.5Covariance..... 92.3Covariance..... 96.2Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....  5.0Covariance..... 10.0Covariance..... 15.0Covariance..... 20.0Covariance..... 25.0Covariance..... 30.0Covariance..... 35.0Covariance..... 40.0Covariance..... 45.0Covariance..... 50.0Covariance..... 55.0Covariance..... 60.0Covariance..... 65.0Covariance..... 70.0Covariance..... 75.0Covariance..... 80.0Covariance..... 85.0Covariance..... 90.0Covariance..... 95.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....done
# Covariance.....  0.0Covariance.....  0.0Covariance.....  1.1Covariance.....  2.1Covariance.....  3.2Covariance.....  4.2Covariance.....  5.3Covariance.....  6.3Covariance.....  7.4Covariance.....  8.4Covariance.....  9.5Covariance..... 10.5Covariance..... 11.6Covariance..... 12.6Covariance..... 13.7Covariance..... 14.7Covariance..... 15.8Covariance..... 16.8Covariance..... 17.9Covariance..... 18.9Covariance..... 20.0Covariance..... 21.1Covariance..... 22.1Covariance..... 23.2Covariance..... 24.2Covariance..... 25.3Covariance..... 26.3Covariance..... 27.4Covariance..... 28.4Covariance..... 29.5Covariance..... 30.5Covariance..... 31.6Covariance..... 32.6Covariance..... 33.7Covariance..... 34.7Covariance..... 35.8Covariance..... 36.8Covariance..... 37.9Covariance..... 38.9Covariance..... 40.0Covariance..... 41.1Covariance..... 42.1Covariance..... 43.2Covariance..... 44.2Covariance..... 45.3Covariance..... 46.3Covariance..... 47.4Covariance..... 48.4Covariance..... 49.5Covariance..... 50.5Covariance..... 51.6Covariance..... 52.6Covariance..... 53.7Covariance..... 54.7Covariance..... 55.8Covariance..... 56.8Covariance..... 57.9Covariance..... 58.9Covariance..... 60.0Covariance..... 61.1Covariance..... 62.1Covariance..... 63.2Covariance..... 64.2Covariance..... 65.3Covariance..... 66.3Covariance..... 67.4Covariance..... 68.4Covariance..... 69.5Covariance..... 70.5Covariance..... 71.6Covariance..... 72.6Covariance..... 73.7Covariance..... 74.7Covariance..... 75.8Covariance..... 76.8Covariance..... 77.9Covariance..... 78.9Covariance..... 80.0Covariance..... 81.1Covariance..... 82.1Covariance..... 83.2Covariance..... 84.2Covariance..... 85.3Covariance..... 86.3Covariance..... 87.4Covariance..... 88.4Covariance..... 89.5Covariance..... 90.5Covariance..... 91.6Covariance..... 92.6Covariance..... 93.7Covariance..... 94.7Covariance..... 95.8Covariance..... 96.8Covariance..... 97.9Covariance..... 98.9Covariance.....done
# 220

# %%
img_fld = fld.transform(img)
v = imshow(img_fld[:,:,:3])

# %%
classes.transform(fld.transform)
gmlc = GaussianClassifier(classes)
clmap = gmlc.classify_image(img_fld)
clmap_trainig = clmap * (gt != 0)
v = imshow(classes = clmap_trainig)
